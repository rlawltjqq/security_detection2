# %%
import cv2
cap = cv2.VideoCapture(0)
if cap.isOpened:
    file_path = 'D:\\pass\\test.mp4'
    fps = 25.40
    fourcc = cv2.VideoWriter_fourcc(*'DIVX')            # 인코딩 포맷 문자
    width = cap.get(cv2.CAP_PROP_FRAME_WIDTH)
    height = cap.get(cv2.CAP_PROP_FRAME_HEIGHT)
    size = (int(width), int (height))                   # 프레임 크기
    
    out = cv2.VideoWriter(file_path, fourcc, fps, size) # VideoWriter 객체 생성
    while True:
        ret, frame = cap.read()
        if ret:
            cv2.imshow('camera-recording', frame)
            out.write(frame)                            # 파일 저장
            if cv2.waitKey(int(1000/fps)) != -1:
                break
        else:
            print('no file!')
            break
    out.release()                                       # 파일 닫기
else:
    print("Can`t open camera!")
cap.release()
cv2.destroyAllWindows()

# %%
import cv2

capture = cv2.VideoCapture(0)
#         
if capture.isOpened():
 #             
 capture .set(cv2.CAP_PROP_FRAME_WIDTH, 640)
 capture .set(cv2.CAP_PROP_FRAME_HEIGHT, 480)
 
 #          
 while True:
  read_code, frame = capture.read()
  if not read_code:
   break
  cv2.imshow("screen_title", frame)
  #    q  ，         
  if cv2.waitKey(1) == ord('q'):
   #        
   frame = cv2.resize(frame, (1920, 1080))
   cv2.imwrite('pic.jpg', frame)
   break
 #       
 capture.release()
 cv2.destroyWindow("screen_title")

# %%
import cv2

capture = cv2.VideoCapture(0)
capture_usb = cv2.VideoCapture(1)
#         
if capture.isOpened():
 if capture_usb.isOpened():
 #           
  capture.set(cv2.CAP_PROP_FRAME_WIDTH, 416)
  capture.set(cv2.CAP_PROP_FRAME_HEIGHT, 416)
  capture_usb.set(cv2.CAP_PROP_FRAME_WIDTH, 416)
  capture_usb.set(cv2.CAP_PROP_FRAME_HEIGHT, 416)
 
 #          
 while True:
  read_code, frame = capture.read()
  read_code2, frame2 = capture_usb.read()
  if not read_code or not read_code2:
   break
  cv2.imshow("screen_title", frame)
  cv2.imshow("screen_title_usb", frame2)
  #    q  ，         
  if cv2.waitKey(1) == ord('q'):
   #        
   frame = cv2.resize(frame, (416, 416))
   cv2.imwrite('pic.jpg', frame)
   capture_usb.release()
   break
 #       
 capture.release()
 cv2.destroyWindow("screen_title")
